# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
items = [2,3,4,5]
np_items = np.array(items)
gt_items = np_items > 3
plt.plot(np_items)
plt.show()
plt.hist(np_items)
plt.show()
plt.clf()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
mc = pd.read_csv('/home/ini/Downloads/zip-files/archive/MostCrowded100inWorld.csv', index_col=0)
# print(mc)
china = mc.loc[:'5.', ['Country/Dependency','Population', 'Date']]
# print(china)
n=countries = mc.loc['1.':'5.', 'Country/Dependency']
# print(np_countries)
population = mc.loc['1.':'5.', 'Population']

pd_data = pd.DataFrame({
    'countries': ['China', 'India', 'USA', 'Indonesia', 'Pakistan'],
    'population': [1412600, 1375586, 334200, 275773, 235825]
})

pd_data.set_index('countries', inplace = True)
print(pd_data)
pd_data.plot(x='countries', y='population', kind='pie', autopct='%1.0f%%')
plt.show()
# Out:
#            population
# countries
# China         1412600
# India         1375586
# USA            334200
# Indonesia      275773
# Pakistan       235825
