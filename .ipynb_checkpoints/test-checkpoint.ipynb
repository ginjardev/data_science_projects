# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
items = [2,3,4,5]
np_items = np.array(items)
gt_items = np_items > 3
plt.plot(np_items)
plt.show()
plt.hist(np_items)
plt.show()
plt.clf()

# %%
import pandas as pd
import matplotlib.pyplot as plt

mc = pd.read_csv('/home/ini/Downloads/zip-files/archive/MostCrowded100inWorld.csv', index_col=0)
# print(mc)
china = mc.loc[:'5.', ['Country/Dependency','Population', 'Date']]
# print(china)
np_countries = np.array(mc.loc['1.':'5.', 'Country/Dependency'])
print(np_countries)
np_population = np.array(mc.loc['1.':'5.', 'Population'])
print(np_population)
pop = np_population
# plt.pie(np_population)
# plt.show()
# Out:
# ['China' 'India' '\xa0United States' 'Indonesia' 'Pakistan']
# ['1,412,600,000' '1,375,586,000' '334,200,979' '275,773,800' '235,825,000']
